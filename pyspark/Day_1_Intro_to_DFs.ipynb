# %%
a = 10

# %%
type(a)
# Out:
# int

# %%
sc

# %%
rdd = sc.textFile("/sample/myfile.txt")
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File <command-6569350819339326>, line 1
# ----> 1 rdd = sc.textFile("/sample/myfile.txt")
#
# File /databricks/python_shell/lib/dbruntime/UserNamespaceInitializer.py:69, in TripWire.__getattr__(self, item)
#      68 def __getattr__(self, item):
# ---> 69     self._raise()
#
# File /databricks/python_shell/lib/dbruntime/UserNamespaceInitializer.py:56, in TripWire._raise(self)
#      53     else:
#      54         not_implemented_exception = NotImplementedError(
#      55             self._UNSUPPORTED_SERVERLESS.format(self.name))
# ---> 56         raise patch_exception_with_error_details(
#      57             not_implemented_exception,
#      58             DriverErrorCode.UNSUPPORTED_ON_SERVERLESS_COMPUTE  # type: ignore[attr-defined]
#      59         )
#      60 elif mode == SparkMode.PIPELINE_UDS_CONNECT:
# ...

# %%
rdd = sc.textFile("/sample/myfile.txt")

# %%
spark

# %%
my_DF = spark.read.text("dbfs:/sample/myfile.txt")

# %%
my_DF1 = spark.read.text("myfile.txt")

# %%
type(my_DF)
# Out:
# pyspark.sql.connect.dataframe.DataFrame

# %%
my_DF.show()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperationException             Traceback (most recent call last)
# File <command-6569350819339332>, line 1
# ----> 1 my_DF.show()
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/dataframe.py:1156, in DataFrame.show(self, n, truncate, vertical)
#    1155 def show(self, n: int = 20, truncate: Union[bool, int] = True, vertical: bool = False) -> None:
# -> 1156     print(self._show_string(n, truncate, vertical))
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/dataframe.py:909, in DataFrame._show_string(self, n, truncate, vertical)
#     892     except ValueError:
#     893         raise PySparkTypeError(
#     894             errorClass="NOT_BOOL",
#     895             messageParameters={
#    (...)
#     898             },
#     899         )
#     901 table, _ = DataFrame(
#     902     plan.ShowString(
#     903         child=self._plan,
# ...

# %%
# %fs ls dbfs:/databricks-datasets/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs head dbfs:/databricks-datasets/README.md
# Out:
# Databricks Hosted Datasets
# ...
#
# The data contained within this directory is hosted for users to build
# data pipelines using Apache Spark and Databricks.
#
# License
# -------
# Unless otherwise noted (e.g. within the README for a given data set), the data
# is licensed under Creative Commons Attribution 4.0 International (CC BY 4.0),
# which can be viewed at the following url:
# [http://creativecommons.org/licenses/by/4.0/legalcode](http://creativecommons.org/licenses/by/4.0/legalcode)
#
# Contributions and Requests
# --------------------------
# To request or contribute new datasets to this repository, please send an email
# to: hosted-datasets@databricks.com.
#
# When making the request, include the README.md file you want to publish. Make
# sure the file includes information about the source of the data, the license,
# and how to get additional information. Please ensure the license for this
# data allows it to be hosted by Databricks and consumed by the public.

# %%
my_DF3 = spark.read.text("dbfs:/databricks-datasets/README.md")

# %%
my_DF2.printSchema()
# Out:
# root
#  |-- value: string (nullable = true)

# %%
my_DF.printSchema()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperationException             Traceback (most recent call last)
# File <command-6569350819339339>, line 1
# ----> 1 my_DF.printSchema()
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/dataframe.py:2015, in DataFrame.printSchema(self, level)
#    2013     print(self.schema.treeString(level))
#    2014 else:
# -> 2015     print(self.schema.treeString())
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/dataframe.py:1988, in DataFrame.schema(self)
#    1985 @property
#    1986 def schema(self) -> StructType:
#    1987     # self._schema call will cache the schema and serialize it if it is not cached yet.
# -> 1988     _schema = self._schema
#    1989     if self._cached_schema_serialized is not None:
#    1990         try:
#
# ...

# %%
my_DF2 = spark.read.text("dbfs:/databricks-datasets/READM.md")

# %%
my_DF2.printSchema()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-6569350819339341>, line 1
# ----> 1 my_DF2.printSchema()
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/dataframe.py:2015, in DataFrame.printSchema(self, level)
#    2013     print(self.schema.treeString(level))
#    2014 else:
# -> 2015     print(self.schema.treeString())
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/dataframe.py:1988, in DataFrame.schema(self)
#    1985 @property
#    1986 def schema(self) -> StructType:
#    1987     # self._schema call will cache the schema and serialize it if it is not cached yet.
# -> 1988     _schema = self._schema
#    1989     if self._cached_schema_serialized is not None:
#    1990         try:
#
# ...

# %%
my_DF3 = spark.read.text("dbfs:/databricks-datasets/README.md")

# %%
my_DF2.show()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-6569350819339343>, line 1
# ----> 1 my_DF2.show()
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/dataframe.py:1156, in DataFrame.show(self, n, truncate, vertical)
#    1155 def show(self, n: int = 20, truncate: Union[bool, int] = True, vertical: bool = False) -> None:
# -> 1156     print(self._show_string(n, truncate, vertical))
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/dataframe.py:909, in DataFrame._show_string(self, n, truncate, vertical)
#     892     except ValueError:
#     893         raise PySparkTypeError(
#     894             errorClass="NOT_BOOL",
#     895             messageParameters={
#    (...)
#     898             },
#     899         )
#     901 table, _ = DataFrame(
#     902     plan.ShowString(
#     903         child=self._plan,
# ...

# %%
my_DF3.show()
# Out:
# +--------------------+
# |               value|
# +--------------------+
# |Databricks Hosted...|
# |=================...|
# |                    |
# |The data containe...|
# |data pipelines us...|
# |                    |
# |             License|
# |             -------|
# |Unless otherwise ...|
# |is licensed under...|
# |which can be view...|
# |[http://creativec...|
# |                    |
# |Contributions and...|
# |-----------------...|
# |To request or con...|
# |to: hosted-datase...|
# |                    |
# |When making the r...|
# |sure the file inc...|
# +--------------------+
# only showing top 20 rows

# %%
my_DF3.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
my_DF3.count()
# Out:
# 23

# %%
new_DF  =my_DF3.where()
